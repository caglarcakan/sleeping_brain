# %% [markdown]
# # Evolutionary optimization to fMRI and EEG data

# %% [markdown]
# This notebook runs four different optimizations. It simulates the ALN model and runs a multi-objective evolutionary optimization algorithm called the NGSA-II algorithm in `neurolib`.
# The different runs are:
#
# * 1) use fMRI and EEG data simulateneously, apply no filtering (down-to-up solutions)
# * 2) use fMRI and EEG data simulateneously, apply filtering on the median firing rate (up-to-down solutions)
# * 3) use fMRI only without adaptation (b=0)
# * 4) use fMRI only with adaptation (b>=0)
#
# No plots are drawn here. The results of these runs (saved as *.dill files) will be processed and plotted in another notebook.

# %%
# change to the root directory of the project
import os
if os.getcwd().split("/")[-1] == "examples":
    os.chdir('..')
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# %%
# %aimport
# Out:
# Modules to reload:
#
#
# Modules to skip:

# %%
try:
    import matplotlib.pyplot as plt
except ImportError:
    import sys
    # !{sys.executable} -m pip install matplotlib seaborn
    import matplotlib.pyplot as plt
    
import numpy as np
import logging 

from neurolib.models.aln import ALNModel
from neurolib.utils.parameterSpace import ParameterSpace
from neurolib.optimize.evolution import Evolution
import neurolib.utils.functions as func
import neurolib.utils.devutils as du

import neurolib.optimize.evolution.deapUtils as deapUtils

from neurolib.utils.loadData import Dataset
ds = Dataset("gw_big")

# a nice color map
plt.rcParams['image.cmap'] = 'plasma'

# %% [markdown]
# # Initialize model

# %%
model = ALNModel(Cmat = ds.Cmat, Dmat = ds.Dmat) # simulates the whole-brain model in 10s chunks by default if bold == True
# Resting state fits
model.params['dt'] = 0.1
model.params['duration'] = 10 * 60 * 1000 #ms
# testing: aln.params['duration'] = 0.2 * 60 * 1000 #ms
# real: aln.params['duration'] = 1.0 * 60 * 1000 #ms
model.params['save_dt'] = 10.0 # 10 ms sampling steps for saving data, should be multiple of dt
# Out:
# MainProcess root INFO     aln: Model initialized.

# %%
# structural values
model.params["Ke_gl"] = 300.0
model.params["signalV"] = 20.0

# %% [markdown]
# ## Load EEG data

# %%
import dill
f_eeg, mean_eeg_power = dill.load(open("./data/mean_eeg_power_N3.dill", "rb"))

# %%
MEDIAN_KILLER = True

def evaluateSimulation(traj):
    rid = traj.id
    model = evolution.getModelFromTraj(traj)
    model.randomICs()
    defaultDuration = model.params['duration']
    invalid_result = (-np.inf, np.inf, -np.inf, )
    # -------- stage wise simulation --------
    
    # Stage 1 : simulate for a few seconds to see if there is any activity
    # ---------------------------------------
    model.params['duration'] = 11*1000.
    model.run()
    max_amp_output = np.max(
          np.max(model.output[:, model.t > 1000], axis=1) 
        - np.min(model.output[:, model.t > 1000], axis=1)
    )
    max_output = np.max(model.output[:, model.t > 1000])
    
    # check if stage 1 was successful
    # or np.max(model_pwrs) < 1 or np.median(model.output) < 1
    # info: filter of median<1 avoids down-to-up solutions
    # filtering median > 15 avoids finding solutions that stay in the up-state all the time
    if max_output > 160 or max_amp_output < 10 or ((np.median(model.output) < 1 or np.median(model.output) > 15) and MEDIAN_KILLER):
        return invalid_result, {}
    
    # Stage 2: full and final simulation
    # ---------------------------------------
    model.params['duration'] = defaultDuration
    model.run(chunkwise=True, bold = True, chunksize = int(1 * 60 * 1000 / model.params['dt'])) # 1 minute chunks
    
    # -------- fitness evaluation here --------
    fits = du.model_fit(model, ds, fcd=True if model.params.duration >= 5 * 60 * 1000 else False)
    if "fcd" not in fits:
        fits["fcd"] = 1
    
    scores = []
    scores.append(np.mean(fits['fc_scores']))
    scores.append(np.mean(fits['fcd']))
    
    # --- EEG
    
    model_frs, model_pwrs = func.getMeanPowerSpectrum(model.output, dt=model.params.dt, maxfr=40, spectrum_windowsize=10)
    
    # 1/f weighted correlation would be:
    # weights = [0.0] + list(1/model_frs[1:])
    # eeg_correlation = func.weighted_correlation(mean_eeg_power, model_pwrs, weights)
    # unweighted correlation:
    eeg_correlation = np.corrcoef(mean_eeg_power, model_pwrs)[0,1]

    domfr = model_frs[np.argmax(model_pwrs)]    
    scores.append(eeg_correlation)
    
    fitness_tuple = tuple(scores)
    return fitness_tuple, {
        "median_rate" : np.median(model.output),
        "output": model.output[:, ::int(model.params['save_dt']/model.params['dt'])],
        "model_pwrs" : model_pwrs
    }

# %% [markdown]
# # Evolution: No filtering (down-to-up)

# %%
MEDIAN_KILLER = False

# %%
pars = ParameterSpace(['mue_ext_mean', 'mui_ext_mean', 'Ke_gl', 'b', 'tauA', 'sigma_ou'], 
                      [[0.0, 4.0], [0.0, 4.0], [100.0, 400.0], [0.0, 20.0], [5.0, 5000.0], [0.0, 0.5]])

# %%
weightList = [1.0, -1.0, 1.0]
evolution = Evolution(evaluateSimulation, 
                      pars, 
                      weightList = weightList,                   
                      model = model, 
                      ncores=80,
                      POP_INIT_SIZE=640, 
                      POP_SIZE = 160, 
                      NGEN=50, 
                      algorithm='nsga2',
                      filename="evolution-9.0-EEG-no-median-killer.hdf")
# Out:
# MainProcess root INFO     Trajectory Name: results-2020-09-25-18H-45M-00S
# MainProcess root INFO     Storing data to: /mnt/raid/data/cakan/hdf/evolution-9.0-EEG-no-median-killer.hdf
# MainProcess root INFO     Trajectory Name: results-2020-09-25-18H-45M-00S
# MainProcess root INFO     Number of cores: 80
# MainProcess pypet.storageservice.HDF5StorageService INFO     I will use the hdf5 file `/mnt/raid/data/cakan/hdf/evolution-9.0-EEG-no-median-killer.hdf`.
# MainProcess pypet.environment.Environment INFO     Environment initialized.
# MainProcess root INFO     Evolution: Using algorithm: nsga2
# /home/cakan/anaconda/lib/python3.7/site-packages/deap/creator.py:141: RuntimeWarning: A class named 'FitnessMulti' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   RuntimeWarning)
# /home/cakan/anaconda/lib/python3.7/site-packages/deap/creator.py:141: RuntimeWarning: A class named 'Individual' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   RuntimeWarning)
# MainProcess root INFO     Evolution: Individual generation: <function randomParameters at 0x7f6247bcedd0>
# MainProcess root INFO     Evolution: Mating operator: <function cxSimulatedBinaryBounded at 0x7f62501ac680>
# MainProcess root INFO     Evolution: Mutation operator: <function mutPolynomialBounded at 0x7f62501ba9e0>
# MainProcess root INFO     Evolution: Parent selection: <function selTournamentDCD at 0x7f62501b28c0>
# MainProcess root INFO     Evolution: Selection operator: <function selNSGA2 at 0x7f62501ac9e0>

# %%
evolution.run(verbose = False)
# Out:
# MainProcess root INFO     Evaluating initial population of size 640 ...
# MainProcess pypet.trajectory.Trajectory INFO     Your trajectory has not been explored, yet. I will call `f_explore` instead.
# MainProcess pypet.environment.Environment INFO     I am preparing the Trajectory for the experiment and initialise the store.
# MainProcess pypet.environment.Environment INFO     Initialising the storage for the trajectory.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING runs of trajectory
# `results-2020-09-25-18H-45M-00S`.
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.environment.Environment INFO     Starting multiprocessing with at most 80 processes running at the same time.
# MainProcess pypet INFO     PROGRESS: Finished   0/640 runs [                    ]  0.0%
# MainProcess pypet INFO     PROGRESS: Finished  32/640 runs [=                   ]  5.0%, remaining: 0:22:18
# MainProcess pypet INFO     PROGRESS: Finished  64/640 runs [==                  ] 10.0%, remaining: 3:12:18
# MainProcess pypet INFO     PROGRESS: Finished  96/640 runs [===                 ] 15.0%, remaining: 2:10:46
# MainProcess pypet INFO     PROGRESS: Finished 128/640 runs [====                ] 20.0%, remaining: 1:36:19
# MainProcess pypet INFO     PROGRESS: Finished 160/640 runs [=====               ] 25.0%, remaining: 1:53:55
# MainProcess pypet INFO     PROGRESS: Finished 192/640 runs [======              ] 30.0%, remaining: 1:40:02
# MainProcess pypet INFO     PROGRESS: Finished 224/640 runs [=======             ] 35.0%, remaining: 1:23:46
# MainProcess pypet INFO     PROGRESS: Finished 256/640 runs [========            ] 40.0%, remaining: 1:12:02
# MainProcess pypet INFO     PROGRESS: Finished 288/640 runs [=========           ] 45.0%, remaining: 1:04:19
# MainProcess pypet INFO     PROGRESS: Finished 320/640 runs [==========          ] 50.0%, remaining: 1:02:58
# MainProcess pypet INFO     PROGRESS: Finished 352/640 runs [===========         ] 55.0%, remaining: 0:54:20
# MainProcess pypet INFO     PROGRESS: Finished 384/640 runs [============        ] 60.0%, remaining: 0:47:25
# MainProcess pypet INFO     PROGRESS: Finished 416/640 runs [=============       ] 65.0%, remaining: 0:43:59
# MainProcess pypet INFO     PROGRESS: Finished 448/640 runs [==============      ] 70.0%, remaining: 0:37:05
# MainProcess pypet INFO     PROGRESS: Finished 480/640 runs [===============     ] 75.0%, remaining: 0:29:56
# MainProcess pypet INFO     PROGRESS: Finished 512/640 runs [================    ] 80.0%, remaining: 0:23:46
# /home/cakan/anaconda/lib/python3.7/site-packages/numpy/lib/function_base.py:2534: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# /home/cakan/anaconda/lib/python3.7/site-packages/numpy/lib/function_base.py:2535: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# MainProcess pypet INFO     PROGRESS: Finished 544/640 runs [=================   ] 85.0%, remaining: 0:18:21
# MainProcess pypet INFO     PROGRESS: Finished 576/640 runs [==================  ] 90.0%, remaining: 0:12:07
# MainProcess pypet INFO     PROGRESS: Finished 608/640 runs [=================== ] 95.0%, remaining: 0:05:55
# MainProcess pypet INFO     PROGRESS: Finished 640/640 runs [====================]100.0%
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED all runs of trajectory
# `results-2020-09-25-18H-45M-00S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING FINAL STORING of trajectory
# `results-2020-09-25-18H-45M-00S`
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# /home/cakan/anaconda/lib/python3.7/site-packages/pypet/storageservice.py:4597: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   if (np.issubdtype(val.dtype, str) or
# /home/cakan/anaconda/lib/python3.7/site-packages/pypet/storageservice.py:4598: FutureWarning: Conversion of the second argument of issubdtype from `bytes` to `bytes` is deprecated. In future, it will be treated as `np.bytes_ == np.dtype(bytes).type`.
#   np.issubdtype(val.dtype, bytes)):
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# /home/cakan/anaconda/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED FINAL STORING of trajectory
# `results-2020-09-25-18H-45M-00S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO     All runs of trajectory `results-2020-09-25-18H-45M-00S` were completed successfully.
# /mnt/antares_raid/home/cakan/projects/neurolib/neurolib/optimize/evolution/evolutionaryUtils.py:18: UserWarning: Warning: converting a masked element to nan.
#   f"evolution.gen_{gIdx:06d}.scores", np.array([p.fitness.score for p in pop]),
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Processed 376 nodes in 0m20s (18.57 nodes/s).
# MainProcess pypet.storageservice.HDF5StorageService INFO     Processed 657 nodes in 0m40s (16.18 nodes/s).
# MainProcess pypet.storageservice.HDF5StorageService INFO     Processed 938 nodes in 1m00s (15.46 nodes/s).
# MainProcess pypet.storageservice.HDF5StorageService INFO     Processed 1222 nodes in 1m20s (15.12 nodes/s).
# MainProcess pypet.storageservice.HDF5StorageService INFO     Processed 1518 nodes in 1m41s (15.00 nodes/s).
# MainProcess pypet.storageservice.HDF5StorageService INFO     Processed 1793 nodes in 2m01s (14.78 nodes/s).
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess root INFO     Start of evolution
# MainProcess root INFO     Replacing 0 invalid individuals.
# MainProcess pypet.environment.Environment INFO     I am preparing the Trajectory for the experiment and initialise the store.
# MainProcess pypet.environment.Environment INFO     Initialising the storage for the trajectory.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING runs of trajectory
# `results-2020-09-25-18H-45M-00S`.
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.environment.Environment INFO     Starting multiprocessing with at most 80 processes running at the same time.
# MainProcess pypet INFO     PROGRESS: Finished 640/800 runs [================    ] 80.0%
# MainProcess pypet INFO     PROGRESS: Finished 680/800 runs [=================   ] 85.0%, remaining: 1:06:37
# MainProcess pypet INFO     PROGRESS: Finished 720/800 runs [==================  ] 90.0%, remaining: 0:27:41
# /home/cakan/anaconda/lib/python3.7/site-packages/numpy/lib/function_base.py:2534: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# /home/cakan/anaconda/lib/python3.7/site-packages/numpy/lib/function_base.py:2535: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# MainProcess pypet INFO     PROGRESS: Finished 760/800 runs [=================== ] 95.0%, remaining: 0:12:14
# MainProcess pypet INFO     PROGRESS: Finished 800/800 runs [====================]100.0%
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED all runs of trajectory
# `results-2020-09-25-18H-45M-00S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING FINAL STORING of trajectory
# `results-2020-09-25-18H-45M-00S`
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED FINAL STORING of trajectory
# `results-2020-09-25-18H-45M-00S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO     All runs of trajectory `results-2020-09-25-18H-45M-00S` were completed successfully.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess root INFO     ----------- Generation 1 -----------
# MainProcess root INFO     Best individual is [2.3393349028699815, 2.820579209224943, 172.61234694078615, 3.4275166131867207, 4203.238539454751, 0.3399196650241783]
# MainProcess root INFO     Score: 0.39210746260034
# MainProcess root INFO     Fitness: (0.5581300548106225, 0.29621129656507017, 0.9144036295554677)
# MainProcess root INFO     --- Population statistics ---
# MainProcess root INFO     Replacing 0 invalid individuals.
# MainProcess pypet.environment.Environment INFO     I am preparing the Trajectory for the experiment and initialise the store.
# MainProcess pypet.environment.Environment INFO     Initialising the storage for the trajectory.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING runs of trajectory
# `results-2020-09-25-18H-45M-00S`.
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.environment.Environment INFO     Starting multiprocessing with at most 80 processes running at the same time.
# MainProcess pypet INFO     PROGRESS: Finished 800/960 runs [================    ] 83.3%
# MainProcess pypet INFO     PROGRESS: Finished 816/960 runs [=================   ] 85.0%, remaining: 2:46:43
# MainProcess pypet INFO     PROGRESS: Finished 864/960 runs [==================  ] 90.0%, remaining: 0:36:44
# MainProcess pypet INFO     PROGRESS: Finished 912/960 runs [=================== ] 95.0%, remaining: 0:15:22
# MainProcess pypet INFO     PROGRESS: Finished 960/960 runs [====================]100.0%
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED all runs of trajectory
# `results-2020-09-25-18H-45M-00S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING FINAL STORING of trajectory
# `results-2020-09-25-18H-45M-00S`
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED FINAL STORING of trajectory
# `results-2020-09-25-18H-45M-00S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO     All runs of trajectory `results-2020-09-25-18H-45M-00S` were completed successfully.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Processed 1970 nodes in 0m20s (98.50 nodes/s).
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess root INFO     ----------- Generation 2 -----------
# MainProcess root INFO     Best individual is [2.3393349028699815, 2.820579209224943, 172.61234694078615, 3.4275166131867207, 4203.238539454751, 0.3399196650241783]
# MainProcess root INFO     Score: 0.39210746260034
# MainProcess root INFO     Fitness: (0.5581300548106225, 0.29621129656507017, 0.9144036295554677)
# MainProcess root INFO     --- Population statistics ---
# MainProcess root INFO     Replacing 0 invalid individuals.
# MainProcess pypet.environment.Environment INFO     I am preparing the Trajectory for the experiment and initialise the store.
# MainProcess pypet.environment.Environment INFO     Initialising the storage for the trajectory.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING runs of trajectory
# `results-2020-09-25-18H-45M-00S`.
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.environment.Environment INFO     Starting multiprocessing with at most 80 processes running at the same time.
# MainProcess pypet INFO     PROGRESS: Finished 960/1120 runs [=================   ] 85.7%
# MainProcess pypet INFO     PROGRESS: Finished 1008/1120 runs [==================  ] 90.0%, remaining: 0:38:59
# MainProcess pypet INFO     PROGRESS: Finished 1064/1120 runs [=================== ] 95.0%, remaining: 0:10:18
# MainProcess pypet INFO     PROGRESS: Finished 1120/1120 runs [====================]100.0%
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED all runs of trajectory
# `results-2020-09-25-18H-45M-00S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING FINAL STORING of trajectory
# `results-2020-09-25-18H-45M-00S`
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED FINAL STORING of trajectory
# `results-2020-09-25-18H-45M-00S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO     All runs of trajectory `results-2020-09-25-18H-45M-00S` were completed successfully.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess root INFO     ----------- Generation 3 -----------
# MainProcess root INFO     Best individual is [2.3393349028699815, 2.820579209224943, 172.61234694078615, 3.4275166131867207, 4203.238539454751, 0.3399196650241783]
# MainProcess root INFO     Score: 0.39210746260034
# MainProcess root INFO     Fitness: (0.5581300548106225, 0.29621129656507017, 0.9144036295554677)
# MainProcess root INFO     --- Population statistics ---
# MainProcess root INFO     Replacing 0 invalid individuals.
# MainProcess pypet.environment.Environment INFO     I am preparing the Trajectory for the experiment and initialise the store.
# MainProcess pypet.environment.Environment INFO     Initialising the storage for the trajectory.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING runs of trajectory
# `results-2020-09-25-18H-45M-00S`.
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.environment.Environment INFO     Starting multiprocessing with at most 80 processes running at the same time.
# MainProcess pypet INFO     PROGRESS: Finished 1120/1280 runs [=================   ] 87.5%
# MainProcess pypet INFO     PROGRESS: Finished 1152/1280 runs [==================  ] 90.0%, remaining: 0:58:47
# MainProcess pypet INFO     PROGRESS: Finished 1216/1280 runs [=================== ] 95.0%, remaining: 0:12:25
# MainProcess pypet INFO     PROGRESS: Finished 1280/1280 runs [====================]100.0%
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED all runs of trajectory
# `results-2020-09-25-18H-45M-00S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING FINAL STORING of trajectory
# `results-2020-09-25-18H-45M-00S`
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED FINAL STORING of trajectory
# `results-2020-09-25-18H-45M-00S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO     All runs of trajectory `results-2020-09-25-18H-45M-00S` were completed successfully.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess root INFO     ----------- Generation 4 -----------
# MainProcess root INFO     Best individual is [3.2502925652204686, 2.7874297623437503, 238.14351600146026, 15.618271759242605, 4354.946573470742, 0.03425538417405619]
# MainProcess root INFO     Score: 0.40609047262402487
# MainProcess root INFO     Fitness: (0.47858068243813323, 0.24540665484061713, 0.9850973902745586)
# MainProcess root INFO     --- Population statistics ---
# MainProcess root INFO     Replacing 0 invalid individuals.
# MainProcess pypet.environment.Environment INFO     I am preparing the Trajectory for the experiment and initialise the store.
# MainProcess pypet.environment.Environment INFO     Initialising the storage for the trajectory.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING runs of trajectory
# `results-2020-09-25-18H-45M-00S`.
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.environment.Environment INFO     Starting multiprocessing with at most 80 processes running at the same time.
# MainProcess pypet INFO     PROGRESS: Finished 1280/1440 runs [=================   ] 88.9%
# MainProcess pypet INFO     PROGRESS: Finished 1296/1440 runs [==================  ] 90.0%, remaining: 0:14:55
# MainProcess pypet INFO     PROGRESS: Finished 1368/1440 runs [=================== ] 95.0%, remaining: 0:14:54
# MainProcess pypet INFO     PROGRESS: Finished 1440/1440 runs [====================]100.0%
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED all runs of trajectory
# `results-2020-09-25-18H-45M-00S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING FINAL STORING of trajectory
# `results-2020-09-25-18H-45M-00S`
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED FINAL STORING of trajectory
# `results-2020-09-25-18H-45M-00S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO     All runs of trajectory `results-2020-09-25-18H-45M-00S` were completed successfully.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess root INFO     ----------- Generation 5 -----------
# MainProcess root INFO     Best individual is [3.2502925652204686, 2.7874297623437503, 238.14351600146026, 15.618271759242605, 4354.946573470742, 0.03425538417405619]
# MainProcess root INFO     Score: 0.40609047262402487
# MainProcess root INFO     Fitness: (0.47858068243813323, 0.24540665484061713, 0.9850973902745586)
# MainProcess root INFO     --- Population statistics ---
# MainProcess root INFO     Replacing 0 invalid individuals.
# MainProcess pypet.environment.Environment INFO     I am preparing the Trajectory for the experiment and initialise the store.
# MainProcess pypet.environment.Environment INFO     Initialising the storage for the trajectory.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING runs of trajectory
# `results-2020-09-25-18H-45M-00S`.
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.environment.Environment INFO     Starting multiprocessing with at most 80 processes running at the same time.
# MainProcess pypet INFO     PROGRESS: Finished 1440/1600 runs [==================  ] 90.0%
# MainProcess pypet INFO     PROGRESS: Finished 1520/1600 runs [=================== ] 95.0%, remaining: 0:17:30
# MainProcess pypet INFO     PROGRESS: Finished 1600/1600 runs [====================]100.0%
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED all runs of trajectory
# `results-2020-09-25-18H-45M-00S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING FINAL STORING of trajectory
# `results-2020-09-25-18H-45M-00S`
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED FINAL STORING of trajectory
# `results-2020-09-25-18H-45M-00S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO     All runs of trajectory `results-2020-09-25-18H-45M-00S` were completed successfully.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess root INFO     ----------- Generation 6 -----------
# MainProcess root INFO     Best individual is [3.3962387700630203, 3.842663726336765, 267.2048561881159, 17.44924131414381, 4670.15827580876, 0.06563755438887958]
# MainProcess root INFO     Score: 0.41563920647709857
# MainProcess root INFO     Fitness: (0.5160847540587442, 0.25557302585604474, 0.9864058912285961)
# MainProcess root INFO     --- Population statistics ---
# MainProcess root INFO     Replacing 0 invalid individuals.
# MainProcess pypet.environment.Environment INFO     I am preparing the Trajectory for the experiment and initialise the store.
# MainProcess pypet.environment.Environment INFO     Initialising the storage for the trajectory.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING runs of trajectory
# `results-2020-09-25-18H-45M-00S`.
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.environment.Environment INFO     Starting multiprocessing with at most 80 processes running at the same time.
# MainProcess pypet INFO     PROGRESS: Finished 1600/1760 runs [==================  ] 90.9%
# MainProcess pypet INFO     PROGRESS: Finished 1672/1760 runs [=================== ] 95.0%, remaining: 0:23:03
# MainProcess pypet INFO     PROGRESS: Finished 1760/1760 runs [====================]100.0%
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED all runs of trajectory
# `results-2020-09-25-18H-45M-00S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING FINAL STORING of trajectory
# `results-2020-09-25-18H-45M-00S`
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED FINAL STORING of trajectory
# `results-2020-09-25-18H-45M-00S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO     All runs of trajectory `results-2020-09-25-18H-45M-00S` were completed successfully.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess root INFO     ----------- Generation 7 -----------
# MainProcess root INFO     Best individual is [3.3962387700630203, 3.842663726336765, 267.2048561881159, 17.44924131414381, 4670.15827580876, 0.06563755438887958]
# MainProcess root INFO     Score: 0.41563920647709857
# MainProcess root INFO     Fitness: (0.5160847540587442, 0.25557302585604474, 0.9864058912285961)
# MainProcess root INFO     --- Population statistics ---
# MainProcess root INFO     Replacing 0 invalid individuals.
# MainProcess pypet.environment.Environment INFO     I am preparing the Trajectory for the experiment and initialise the store.
# MainProcess pypet.environment.Environment INFO     Initialising the storage for the trajectory.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING runs of trajectory
# `results-2020-09-25-18H-45M-00S`.
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.environment.Environment INFO     Starting multiprocessing with at most 80 processes running at the same time.
# MainProcess pypet INFO     PROGRESS: Finished 1760/1920 runs [==================  ] 91.7%
# MainProcess pypet INFO     PROGRESS: Finished 1824/1920 runs [=================== ] 95.0%, remaining: 0:28:56
# MainProcess pypet INFO     PROGRESS: Finished 1920/1920 runs [====================]100.0%
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED all runs of trajectory
# `results-2020-09-25-18H-45M-00S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING FINAL STORING of trajectory
# `results-2020-09-25-18H-45M-00S`
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED FINAL STORING of trajectory
# `results-2020-09-25-18H-45M-00S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO     All runs of trajectory `results-2020-09-25-18H-45M-00S` were completed successfully.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess root INFO     ----------- Generation 8 -----------
# MainProcess root INFO     Best individual is [3.3962387700630203, 3.842663726336765, 267.2048561881159, 17.44924131414381, 4670.15827580876, 0.06563755438887958]
# MainProcess root INFO     Score: 0.41563920647709857
# MainProcess root INFO     Fitness: (0.5160847540587442, 0.25557302585604474, 0.9864058912285961)
# MainProcess root INFO     --- Population statistics ---
# MainProcess root INFO     Replacing 0 invalid individuals.
# MainProcess pypet.environment.Environment INFO     I am preparing the Trajectory for the experiment and initialise the store.
# MainProcess pypet.environment.Environment INFO     Initialising the storage for the trajectory.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING runs of trajectory
# `results-2020-09-25-18H-45M-00S`.
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.environment.Environment INFO     Starting multiprocessing with at most 80 processes running at the same time.
# MainProcess pypet INFO     PROGRESS: Finished 1920/2080 runs [==================  ] 92.3%
# MainProcess pypet INFO     PROGRESS: Finished 1976/2080 runs [=================== ] 95.0%, remaining: 0:27:56
# MainProcess pypet INFO     PROGRESS: Finished 2080/2080 runs [====================]100.0%
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED all runs of trajectory
# `results-2020-09-25-18H-45M-00S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING FINAL STORING of trajectory
# `results-2020-09-25-18H-45M-00S`
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED FINAL STORING of trajectory
# `results-2020-09-25-18H-45M-00S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO     All runs of trajectory `results-2020-09-25-18H-45M-00S` were completed successfully.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess root INFO     ----------- Generation 9 -----------
# MainProcess root INFO     Best individual is [3.3962387700630203, 3.842663726336765, 267.2048561881159, 17.44924131414381, 4670.15827580876, 0.06563755438887958]
# MainProcess root INFO     Score: 0.41563920647709857
# MainProcess root INFO     Fitness: (0.5160847540587442, 0.25557302585604474, 0.9864058912285961)
# MainProcess root INFO     --- Population statistics ---
# MainProcess root INFO     Replacing 0 invalid individuals.
# ...
# ************************************************************
# FINISHED all runs of trajectory
# `results-2020-09-25-18H-45M-00S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING FINAL STORING of trajectory
# `results-2020-09-25-18H-45M-00S`
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED FINAL STORING of trajectory
# `results-2020-09-25-18H-45M-00S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO     All runs of trajectory `results-2020-09-25-18H-45M-00S` were completed successfully.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess root INFO     ----------- Generation 46 -----------
# MainProcess root INFO     Best individual is [2.355795421695664, 2.947799037734876, 238.14530360274594, 6.020302025741806, 4941.574081759494, 0.36734962700693924]
# MainProcess root INFO     Score: 0.4285209206942647
# MainProcess root INFO     Fitness: (0.566946115701087, 0.24915504219749504, 0.9677716885792021)
# MainProcess root INFO     --- Population statistics ---
# MainProcess root INFO     Replacing 0 invalid individuals.
# MainProcess pypet.environment.Environment INFO     I am preparing the Trajectory for the experiment and initialise the store.
# MainProcess pypet.environment.Environment INFO     Initialising the storage for the trajectory.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING runs of trajectory
# `results-2020-09-25-18H-45M-00S`.
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.environment.Environment INFO     Starting multiprocessing with at most 80 processes running at the same time.
# MainProcess pypet INFO     PROGRESS: Finished 8000/8160 runs [=================== ] 98.0%
# MainProcess pypet INFO     PROGRESS: Finished 8160/8160 runs [====================]100.0%
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED all runs of trajectory
# `results-2020-09-25-18H-45M-00S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING FINAL STORING of trajectory
# `results-2020-09-25-18H-45M-00S`
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED FINAL STORING of trajectory
# `results-2020-09-25-18H-45M-00S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO     All runs of trajectory `results-2020-09-25-18H-45M-00S` were completed successfully.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess root INFO     ----------- Generation 47 -----------
# MainProcess root INFO     Best individual is [2.355795421695664, 2.947799037734876, 238.14530360274594, 6.020302025741806, 4941.574081759494, 0.36734962700693924]
# MainProcess root INFO     Score: 0.4285209206942647
# MainProcess root INFO     Fitness: (0.566946115701087, 0.24915504219749504, 0.9677716885792021)
# MainProcess root INFO     --- Population statistics ---
# MainProcess root INFO     Replacing 0 invalid individuals.
# MainProcess pypet.environment.Environment INFO     I am preparing the Trajectory for the experiment and initialise the store.
# MainProcess pypet.environment.Environment INFO     Initialising the storage for the trajectory.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING runs of trajectory
# `results-2020-09-25-18H-45M-00S`.
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.environment.Environment INFO     Starting multiprocessing with at most 80 processes running at the same time.
# MainProcess pypet INFO     PROGRESS: Finished 8160/8320 runs [=================== ] 98.1%
# MainProcess pypet INFO     PROGRESS: Finished 8320/8320 runs [====================]100.0%
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED all runs of trajectory
# `results-2020-09-25-18H-45M-00S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING FINAL STORING of trajectory
# `results-2020-09-25-18H-45M-00S`
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED FINAL STORING of trajectory
# `results-2020-09-25-18H-45M-00S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO     All runs of trajectory `results-2020-09-25-18H-45M-00S` were completed successfully.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess root INFO     ----------- Generation 48 -----------
# MainProcess root INFO     Best individual is [2.355795421695664, 2.947799037734876, 238.14530360274594, 6.020302025741806, 4941.574081759494, 0.36734962700693924]
# MainProcess root INFO     Score: 0.4285209206942647
# MainProcess root INFO     Fitness: (0.566946115701087, 0.24915504219749504, 0.9677716885792021)
# MainProcess root INFO     --- Population statistics ---
# MainProcess root INFO     Replacing 0 invalid individuals.
# MainProcess pypet.environment.Environment INFO     I am preparing the Trajectory for the experiment and initialise the store.
# MainProcess pypet.environment.Environment INFO     Initialising the storage for the trajectory.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING runs of trajectory
# `results-2020-09-25-18H-45M-00S`.
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.environment.Environment INFO     Starting multiprocessing with at most 80 processes running at the same time.
# MainProcess pypet INFO     PROGRESS: Finished 8320/8480 runs [=================== ] 98.1%
# MainProcess pypet INFO     PROGRESS: Finished 8480/8480 runs [====================]100.0%
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED all runs of trajectory
# `results-2020-09-25-18H-45M-00S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING FINAL STORING of trajectory
# `results-2020-09-25-18H-45M-00S`
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED FINAL STORING of trajectory
# `results-2020-09-25-18H-45M-00S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO     All runs of trajectory `results-2020-09-25-18H-45M-00S` were completed successfully.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess root INFO     ----------- Generation 49 -----------
# MainProcess root INFO     Best individual is [2.355795421695664, 2.947799037734876, 238.14530360274594, 6.020302025741806, 4941.574081759494, 0.36734962700693924]
# MainProcess root INFO     Score: 0.4285209206942647
# MainProcess root INFO     Fitness: (0.566946115701087, 0.24915504219749504, 0.9677716885792021)
# MainProcess root INFO     --- Population statistics ---
# MainProcess root INFO     --- End of evolution ---
# MainProcess root INFO     Best individual is [2.355795421695664, 2.947799037734876, 238.14530360274594, 6.020302025741806, 4941.574081759494, 0.36734962700693924], (0.566946115701087, 0.24915504219749504, 0.9677716885792021)
# MainProcess root INFO     --- End of evolution ---
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-09-25-18H-45M-00S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-09-25-18H-45M-00S`.

# %%
import dill
fname = os.path.join("/mnt/raid/data/cakan/dill/", "evolution-" + evolution.trajectoryName + ".dill")
print(f"Saving evolution to {fname}")
dill.dump(evolution, open(fname, "wb"))
# Out:
# Saving evolution to /mnt/raid/data/cakan/dill/evolution-results-2020-09-25-18H-45M-00S.dill

# %% [markdown]
# # With filtering (up-to-down)

# %%
# this turns on the filter
MEDIAN_KILLER = True

# %%
weightList = [1.0, -1.0, 1.0]
evolution = Evolution(evaluateSimulation, 
                      pars, 
                      weightList = weightList,                   
                      model = model, 
                      ncores=80,
                      POP_INIT_SIZE=640, 
                      POP_SIZE = 160, 
                      NGEN=50, 
                      algorithm='nsga2',
                      filename="evolution-9.0-EEG.hdf")
# Out:
# MainProcess root INFO     Trajectory Name: results-2020-09-27-12H-23M-15S
# MainProcess root INFO     Storing data to: /mnt/raid/data/cakan/hdf/evolution-9.0-EEG.hdf
# MainProcess root INFO     Trajectory Name: results-2020-09-27-12H-23M-15S
# MainProcess root INFO     Number of cores: 80
# MainProcess pypet.storageservice.HDF5StorageService INFO     I will use the hdf5 file `/mnt/raid/data/cakan/hdf/evolution-9.0-EEG.hdf`.
# MainProcess pypet.environment.Environment INFO     Environment initialized.
# MainProcess root INFO     Evolution: Using algorithm: nsga2
# /home/cakan/anaconda/lib/python3.7/site-packages/deap/creator.py:141: RuntimeWarning: A class named 'FitnessMulti' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   RuntimeWarning)
# /home/cakan/anaconda/lib/python3.7/site-packages/deap/creator.py:141: RuntimeWarning: A class named 'Individual' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   RuntimeWarning)
# MainProcess root INFO     Evolution: Individual generation: <function randomParameters at 0x7f6247bcedd0>
# MainProcess root INFO     Evolution: Mating operator: <function cxSimulatedBinaryBounded at 0x7f62501ac680>
# MainProcess root INFO     Evolution: Mutation operator: <function mutPolynomialBounded at 0x7f62501ba9e0>
# MainProcess root INFO     Evolution: Parent selection: <function selTournamentDCD at 0x7f62501b28c0>
# MainProcess root INFO     Evolution: Selection operator: <function selNSGA2 at 0x7f62501ac9e0>

# %%
evolution.run(verbose = False)
# Out:
# MainProcess root INFO     Evaluating initial population of size 640 ...
# MainProcess pypet.trajectory.Trajectory INFO     Your trajectory has not been explored, yet. I will call `f_explore` instead.
# MainProcess pypet.environment.Environment INFO     I am preparing the Trajectory for the experiment and initialise the store.
# MainProcess pypet.environment.Environment INFO     Initialising the storage for the trajectory.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING runs of trajectory
# `results-2020-09-27-12H-23M-15S`.
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.environment.Environment INFO     Starting multiprocessing with at most 80 processes running at the same time.
# MainProcess pypet INFO     PROGRESS: Finished   0/640 runs [                    ]  0.0%
# MainProcess pypet INFO     PROGRESS: Finished  32/640 runs [=                   ]  5.0%, remaining: 0:11:22
# MainProcess pypet INFO     PROGRESS: Finished  64/640 runs [==                  ] 10.0%, remaining: 0:09:59
# MainProcess pypet INFO     PROGRESS: Finished  96/640 runs [===                 ] 15.0%, remaining: 0:09:11
# MainProcess pypet INFO     PROGRESS: Finished 128/640 runs [====                ] 20.0%, remaining: 0:08:24
# MainProcess pypet INFO     PROGRESS: Finished 160/640 runs [=====               ] 25.0%, remaining: 0:08:05
# MainProcess pypet INFO     PROGRESS: Finished 192/640 runs [======              ] 30.0%, remaining: 0:07:30
# MainProcess pypet INFO     PROGRESS: Finished 224/640 runs [=======             ] 35.0%, remaining: 0:07:06
# MainProcess pypet INFO     PROGRESS: Finished 256/640 runs [========            ] 40.0%, remaining: 0:07:11
# MainProcess pypet INFO     PROGRESS: Finished 288/640 runs [=========           ] 45.0%, remaining: 0:07:02
# MainProcess pypet INFO     PROGRESS: Finished 320/640 runs [==========          ] 50.0%, remaining: 0:06:47
# MainProcess pypet INFO     PROGRESS: Finished 352/640 runs [===========         ] 55.0%, remaining: 0:06:27
# MainProcess pypet INFO     PROGRESS: Finished 384/640 runs [============        ] 60.0%, remaining: 0:06:06
# MainProcess pypet INFO     PROGRESS: Finished 416/640 runs [=============       ] 65.0%, remaining: 0:05:43
# MainProcess pypet INFO     PROGRESS: Finished 448/640 runs [==============      ] 70.0%, remaining: 0:05:14
# MainProcess pypet INFO     PROGRESS: Finished 480/640 runs [===============     ] 75.0%, remaining: 0:04:43
# MainProcess pypet INFO     PROGRESS: Finished 512/640 runs [================    ] 80.0%, remaining: 0:03:54
# MainProcess pypet INFO     PROGRESS: Finished 544/640 runs [=================   ] 85.0%, remaining: 0:03:02
# MainProcess pypet INFO     PROGRESS: Finished 576/640 runs [==================  ] 90.0%, remaining: 0:02:12
# MainProcess pypet INFO     PROGRESS: Finished 608/640 runs [=================== ] 95.0%, remaining: 0:01:12
# MainProcess pypet INFO     PROGRESS: Finished 640/640 runs [====================]100.0%
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED all runs of trajectory
# `results-2020-09-27-12H-23M-15S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING FINAL STORING of trajectory
# `results-2020-09-27-12H-23M-15S`
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# /home/cakan/anaconda/lib/python3.7/site-packages/pypet/storageservice.py:4597: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   if (np.issubdtype(val.dtype, str) or
# /home/cakan/anaconda/lib/python3.7/site-packages/pypet/storageservice.py:4598: FutureWarning: Conversion of the second argument of issubdtype from `bytes` to `bytes` is deprecated. In future, it will be treated as `np.bytes_ == np.dtype(bytes).type`.
#   np.issubdtype(val.dtype, bytes)):
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# /home/cakan/anaconda/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED FINAL STORING of trajectory
# `results-2020-09-27-12H-23M-15S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO     All runs of trajectory `results-2020-09-27-12H-23M-15S` were completed successfully.
# /mnt/antares_raid/home/cakan/projects/neurolib/neurolib/optimize/evolution/evolutionaryUtils.py:18: UserWarning: Warning: converting a masked element to nan.
#   f"evolution.gen_{gIdx:06d}.scores", np.array([p.fitness.score for p in pop]),
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Processed 733 nodes in 0m20s (36.65 nodes/s).
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess root INFO     Start of evolution
# MainProcess root INFO     Replacing 53 invalid individuals.
# MainProcess pypet.environment.Environment INFO     I am preparing the Trajectory for the experiment and initialise the store.
# MainProcess pypet.environment.Environment INFO     Initialising the storage for the trajectory.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING runs of trajectory
# `results-2020-09-27-12H-23M-15S`.
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.environment.Environment INFO     Starting multiprocessing with at most 80 processes running at the same time.
# MainProcess pypet INFO     PROGRESS: Finished 640/853 runs [===============     ] 75.0%
# MainProcess pypet INFO     PROGRESS: Finished 683/853 runs [================    ] 80.1%, remaining: 0:08:23
# MainProcess pypet INFO     PROGRESS: Finished 726/853 runs [=================   ] 85.1%, remaining: 0:19:21
# MainProcess pypet INFO     PROGRESS: Finished 811/853 runs [=================== ] 95.1%, remaining: 0:04:36
# MainProcess pypet INFO     PROGRESS: Finished 853/853 runs [====================]100.0%
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED all runs of trajectory
# `results-2020-09-27-12H-23M-15S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING FINAL STORING of trajectory
# `results-2020-09-27-12H-23M-15S`
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED FINAL STORING of trajectory
# `results-2020-09-27-12H-23M-15S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO     All runs of trajectory `results-2020-09-27-12H-23M-15S` were completed successfully.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Processed 341 nodes in 0m20s (16.92 nodes/s).
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess root INFO     ----------- Generation 1 -----------
# MainProcess root INFO     Best individual is [3.310956621876819, 3.5292328095084096, 359.3149144058607, 3.8444459728788183, 4831.380247702503, 0.20284521491442706]
# MainProcess root INFO     Score: 0.3185557788575139
# MainProcess root INFO     Fitness: (0.4975728040028397, 0.33326613986991344, 0.7913606724396154)
# MainProcess root INFO     --- Population statistics ---
# MainProcess root INFO     Replacing 0 invalid individuals.
# MainProcess pypet.environment.Environment INFO     I am preparing the Trajectory for the experiment and initialise the store.
# MainProcess pypet.environment.Environment INFO     Initialising the storage for the trajectory.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING runs of trajectory
# `results-2020-09-27-12H-23M-15S`.
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.environment.Environment INFO     Starting multiprocessing with at most 80 processes running at the same time.
# MainProcess pypet INFO     PROGRESS: Finished 853/1013 runs [================    ] 84.2%
# MainProcess pypet INFO     PROGRESS: Finished 862/1013 runs [=================   ] 85.1%, remaining: 0:05:46
# MainProcess pypet INFO     PROGRESS: Finished 912/1013 runs [==================  ] 90.0%, remaining: 0:05:45
# MainProcess pypet INFO     PROGRESS: Finished 963/1013 runs [=================== ] 95.1%, remaining: 0:07:12
# MainProcess pypet INFO     PROGRESS: Finished 1013/1013 runs [====================]100.0%
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED all runs of trajectory
# `results-2020-09-27-12H-23M-15S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING FINAL STORING of trajectory
# `results-2020-09-27-12H-23M-15S`
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED FINAL STORING of trajectory
# `results-2020-09-27-12H-23M-15S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO     All runs of trajectory `results-2020-09-27-12H-23M-15S` were completed successfully.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess root INFO     ----------- Generation 2 -----------
# MainProcess root INFO     Best individual is [3.310956621876819, 3.5292328095084096, 359.3149144058607, 3.8444459728788183, 4831.380247702503, 0.20284521491442706]
# MainProcess root INFO     Score: 0.3185557788575139
# MainProcess root INFO     Fitness: (0.4975728040028397, 0.33326613986991344, 0.7913606724396154)
# MainProcess root INFO     --- Population statistics ---
# MainProcess root INFO     Replacing 0 invalid individuals.
# MainProcess pypet.environment.Environment INFO     I am preparing the Trajectory for the experiment and initialise the store.
# MainProcess pypet.environment.Environment INFO     Initialising the storage for the trajectory.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING runs of trajectory
# `results-2020-09-27-12H-23M-15S`.
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.environment.Environment INFO     Starting multiprocessing with at most 80 processes running at the same time.
# MainProcess pypet INFO     PROGRESS: Finished 1013/1173 runs [=================   ] 86.4%
# MainProcess pypet INFO     PROGRESS: Finished 1056/1173 runs [==================  ] 90.0%, remaining: 0:05:44
# MainProcess pypet INFO     PROGRESS: Finished 1115/1173 runs [=================== ] 95.1%, remaining: 0:08:57
# MainProcess pypet INFO     PROGRESS: Finished 1173/1173 runs [====================]100.0%
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED all runs of trajectory
# `results-2020-09-27-12H-23M-15S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING FINAL STORING of trajectory
# `results-2020-09-27-12H-23M-15S`
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED FINAL STORING of trajectory
# `results-2020-09-27-12H-23M-15S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO     All runs of trajectory `results-2020-09-27-12H-23M-15S` were completed successfully.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess root INFO     ----------- Generation 3 -----------
# MainProcess root INFO     Best individual is [3.310956621876819, 3.5292328095084096, 359.3149144058607, 3.8444459728788183, 4831.380247702503, 0.20284521491442706]
# MainProcess root INFO     Score: 0.3185557788575139
# MainProcess root INFO     Fitness: (0.4975728040028397, 0.33326613986991344, 0.7913606724396154)
# MainProcess root INFO     --- Population statistics ---
# MainProcess root INFO     Replacing 0 invalid individuals.
# MainProcess pypet.environment.Environment INFO     I am preparing the Trajectory for the experiment and initialise the store.
# MainProcess pypet.environment.Environment INFO     Initialising the storage for the trajectory.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING runs of trajectory
# `results-2020-09-27-12H-23M-15S`.
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.environment.Environment INFO     Starting multiprocessing with at most 80 processes running at the same time.
# MainProcess pypet INFO     PROGRESS: Finished 1173/1333 runs [=================   ] 88.0%
# MainProcess pypet INFO     PROGRESS: Finished 1200/1333 runs [==================  ] 90.0%, remaining: 0:05:04
# MainProcess pypet INFO     PROGRESS: Finished 1267/1333 runs [=================== ] 95.0%, remaining: 0:10:45
# MainProcess pypet INFO     PROGRESS: Finished 1333/1333 runs [====================]100.0%
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED all runs of trajectory
# `results-2020-09-27-12H-23M-15S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING FINAL STORING of trajectory
# `results-2020-09-27-12H-23M-15S`
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED FINAL STORING of trajectory
# `results-2020-09-27-12H-23M-15S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO     All runs of trajectory `results-2020-09-27-12H-23M-15S` were completed successfully.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess root INFO     ----------- Generation 4 -----------
# MainProcess root INFO     Best individual is [3.310956621876819, 3.5292328095084096, 359.3149144058607, 3.8444459728788183, 4831.380247702503, 0.20284521491442706]
# MainProcess root INFO     Score: 0.3185557788575139
# MainProcess root INFO     Fitness: (0.4975728040028397, 0.33326613986991344, 0.7913606724396154)
# MainProcess root INFO     --- Population statistics ---
# MainProcess root INFO     Replacing 0 invalid individuals.
# MainProcess pypet.environment.Environment INFO     I am preparing the Trajectory for the experiment and initialise the store.
# MainProcess pypet.environment.Environment INFO     Initialising the storage for the trajectory.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING runs of trajectory
# `results-2020-09-27-12H-23M-15S`.
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.environment.Environment INFO     Starting multiprocessing with at most 80 processes running at the same time.
# MainProcess pypet INFO     PROGRESS: Finished 1333/1493 runs [=================   ] 89.3%
# MainProcess pypet INFO     PROGRESS: Finished 1344/1493 runs [==================  ] 90.0%, remaining: 0:05:15
# MainProcess pypet INFO     PROGRESS: Finished 1419/1493 runs [=================== ] 95.0%, remaining: 0:13:04
# MainProcess pypet INFO     PROGRESS: Finished 1493/1493 runs [====================]100.0%
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED all runs of trajectory
# `results-2020-09-27-12H-23M-15S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING FINAL STORING of trajectory
# `results-2020-09-27-12H-23M-15S`
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED FINAL STORING of trajectory
# `results-2020-09-27-12H-23M-15S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO     All runs of trajectory `results-2020-09-27-12H-23M-15S` were completed successfully.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess root INFO     ----------- Generation 5 -----------
# MainProcess root INFO     Best individual is [3.4046016317522376, 3.5292328095084096, 280.07325388360215, 3.8113262931880962, 4887.308909944147, 0.34000489658593047]
# MainProcess root INFO     Score: 0.3196055362277618
# MainProcess root INFO     Fitness: (0.5568542193369368, 0.5305142315755523, 0.9324766209219009)
# MainProcess root INFO     --- Population statistics ---
# MainProcess root INFO     Replacing 0 invalid individuals.
# MainProcess pypet.environment.Environment INFO     I am preparing the Trajectory for the experiment and initialise the store.
# MainProcess pypet.environment.Environment INFO     Initialising the storage for the trajectory.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING runs of trajectory
# `results-2020-09-27-12H-23M-15S`.
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.environment.Environment INFO     Starting multiprocessing with at most 80 processes running at the same time.
# MainProcess pypet INFO     PROGRESS: Finished 1493/1653 runs [==================  ] 90.3%
# MainProcess pypet INFO     PROGRESS: Finished 1571/1653 runs [=================== ] 95.0%, remaining: 0:12:28
# MainProcess pypet INFO     PROGRESS: Finished 1653/1653 runs [====================]100.0%
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED all runs of trajectory
# `results-2020-09-27-12H-23M-15S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING FINAL STORING of trajectory
# `results-2020-09-27-12H-23M-15S`
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED FINAL STORING of trajectory
# `results-2020-09-27-12H-23M-15S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO     All runs of trajectory `results-2020-09-27-12H-23M-15S` were completed successfully.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess root INFO     ----------- Generation 6 -----------
# MainProcess root INFO     Best individual is [2.5594076302994306, 2.3908264348368276, 113.9052832709581, 2.2767475264029335, 3250.9339787226295, 0.2110029062403946]
# MainProcess root INFO     Score: 0.3887597487602768
# MainProcess root INFO     Fitness: (0.5489767608862991, 0.29656339031339024, 0.9138658757079215)
# MainProcess root INFO     --- Population statistics ---
# MainProcess root INFO     Replacing 0 invalid individuals.
# MainProcess pypet.environment.Environment INFO     I am preparing the Trajectory for the experiment and initialise the store.
# MainProcess pypet.environment.Environment INFO     Initialising the storage for the trajectory.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING runs of trajectory
# `results-2020-09-27-12H-23M-15S`.
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.environment.Environment INFO     Starting multiprocessing with at most 80 processes running at the same time.
# MainProcess pypet INFO     PROGRESS: Finished 1653/1813 runs [==================  ] 91.2%
# MainProcess pypet INFO     PROGRESS: Finished 1723/1813 runs [=================== ] 95.0%, remaining: 0:18:47
# MainProcess pypet INFO     PROGRESS: Finished 1813/1813 runs [====================]100.0%
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED all runs of trajectory
# `results-2020-09-27-12H-23M-15S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING FINAL STORING of trajectory
# `results-2020-09-27-12H-23M-15S`
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED FINAL STORING of trajectory
# `results-2020-09-27-12H-23M-15S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO     All runs of trajectory `results-2020-09-27-12H-23M-15S` were completed successfully.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess root INFO     ----------- Generation 7 -----------
# MainProcess root INFO     Best individual is [2.5594076302994306, 2.3908264348368276, 113.9052832709581, 2.2767475264029335, 3250.9339787226295, 0.2110029062403946]
# MainProcess root INFO     Score: 0.3887597487602768
# MainProcess root INFO     Fitness: (0.5489767608862991, 0.29656339031339024, 0.9138658757079215)
# MainProcess root INFO     --- Population statistics ---
# MainProcess root INFO     Replacing 0 invalid individuals.
# MainProcess pypet.environment.Environment INFO     I am preparing the Trajectory for the experiment and initialise the store.
# MainProcess pypet.environment.Environment INFO     Initialising the storage for the trajectory.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING runs of trajectory
# `results-2020-09-27-12H-23M-15S`.
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.environment.Environment INFO     Starting multiprocessing with at most 80 processes running at the same time.
# MainProcess pypet INFO     PROGRESS: Finished 1813/1973 runs [==================  ] 91.9%
# MainProcess pypet INFO     PROGRESS: Finished 1875/1973 runs [=================== ] 95.0%, remaining: 0:03:34
# MainProcess pypet INFO     PROGRESS: Finished 1973/1973 runs [====================]100.0%
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED all runs of trajectory
# `results-2020-09-27-12H-23M-15S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING FINAL STORING of trajectory
# `results-2020-09-27-12H-23M-15S`
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED FINAL STORING of trajectory
# `results-2020-09-27-12H-23M-15S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO     All runs of trajectory `results-2020-09-27-12H-23M-15S` were completed successfully.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess root INFO     ----------- Generation 8 -----------
# MainProcess root INFO     Best individual is [2.5594076302994306, 2.3908264348368276, 113.9052832709581, 2.2767475264029335, 3250.9339787226295, 0.2110029062403946]
# MainProcess root INFO     Score: 0.3887597487602768
# MainProcess root INFO     Fitness: (0.5489767608862991, 0.29656339031339024, 0.9138658757079215)
# MainProcess root INFO     --- Population statistics ---
# MainProcess root INFO     Replacing 0 invalid individuals.
# MainProcess pypet.environment.Environment INFO     I am preparing the Trajectory for the experiment and initialise the store.
# MainProcess pypet.environment.Environment INFO     Initialising the storage for the trajectory.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING runs of trajectory
# `results-2020-09-27-12H-23M-15S`.
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.environment.Environment INFO     Starting multiprocessing with at most 80 processes running at the same time.
# MainProcess pypet INFO     PROGRESS: Finished 1973/2133 runs [==================  ] 92.5%
# MainProcess pypet INFO     PROGRESS: Finished 2027/2133 runs [=================== ] 95.0%, remaining: 0:04:00
# MainProcess pypet INFO     PROGRESS: Finished 2133/2133 runs [====================]100.0%
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED all runs of trajectory
# `results-2020-09-27-12H-23M-15S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING FINAL STORING of trajectory
# `results-2020-09-27-12H-23M-15S`
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED FINAL STORING of trajectory
# `results-2020-09-27-12H-23M-15S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO     All runs of trajectory `results-2020-09-27-12H-23M-15S` were completed successfully.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess root INFO     ----------- Generation 9 -----------
# MainProcess root INFO     Best individual is [2.5594076302994306, 2.3908264348368276, 113.9052832709581, 2.2767475264029335, 3250.9339787226295, 0.2110029062403946]
# MainProcess root INFO     Score: 0.3887597487602768
# MainProcess root INFO     Fitness: (0.5489767608862991, 0.29656339031339024, 0.9138658757079215)
# MainProcess root INFO     --- Population statistics ---
# MainProcess root INFO     Replacing 0 invalid individuals.
# MainProcess pypet.environment.Environment INFO     I am preparing the Trajectory for the experiment and initialise the store.
# MainProcess pypet.environment.Environment INFO     Initialising the storage for the trajectory.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING runs of trajectory
# `results-2020-09-27-12H-23M-15S`.
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.environment.Environment INFO     Starting multiprocessing with at most 80 processes running at the same time.
# ...
# ************************************************************
# FINISHED all runs of trajectory
# `results-2020-09-27-12H-23M-15S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING FINAL STORING of trajectory
# `results-2020-09-27-12H-23M-15S`
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED FINAL STORING of trajectory
# `results-2020-09-27-12H-23M-15S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO     All runs of trajectory `results-2020-09-27-12H-23M-15S` were completed successfully.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess root INFO     ----------- Generation 46 -----------
# MainProcess root INFO     Best individual is [3.5780081051007655, 3.5178093150738436, 262.10029036759965, 3.74785670831588, 4943.375342335516, 0.34106454868006486]
# MainProcess root INFO     Score: 0.4115977559522552
# MainProcess root INFO     Fitness: (0.5585464266517041, 0.2528170859538784, 0.9290639271589399)
# MainProcess root INFO     --- Population statistics ---
# MainProcess root INFO     Replacing 0 invalid individuals.
# MainProcess pypet.environment.Environment INFO     I am preparing the Trajectory for the experiment and initialise the store.
# MainProcess pypet.environment.Environment INFO     Initialising the storage for the trajectory.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING runs of trajectory
# `results-2020-09-27-12H-23M-15S`.
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.environment.Environment INFO     Starting multiprocessing with at most 80 processes running at the same time.
# MainProcess pypet INFO     PROGRESS: Finished 8053/8213 runs [=================== ] 98.1%
# MainProcess pypet INFO     PROGRESS: Finished 8213/8213 runs [====================]100.0%
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED all runs of trajectory
# `results-2020-09-27-12H-23M-15S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING FINAL STORING of trajectory
# `results-2020-09-27-12H-23M-15S`
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED FINAL STORING of trajectory
# `results-2020-09-27-12H-23M-15S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO     All runs of trajectory `results-2020-09-27-12H-23M-15S` were completed successfully.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess root INFO     ----------- Generation 47 -----------
# MainProcess root INFO     Best individual is [3.5780081051007655, 3.5178093150738436, 262.10029036759965, 3.74785670831588, 4943.375342335516, 0.34106454868006486]
# MainProcess root INFO     Score: 0.4115977559522552
# MainProcess root INFO     Fitness: (0.5585464266517041, 0.2528170859538784, 0.9290639271589399)
# MainProcess root INFO     --- Population statistics ---
# MainProcess root INFO     Replacing 0 invalid individuals.
# MainProcess pypet.environment.Environment INFO     I am preparing the Trajectory for the experiment and initialise the store.
# MainProcess pypet.environment.Environment INFO     Initialising the storage for the trajectory.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING runs of trajectory
# `results-2020-09-27-12H-23M-15S`.
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.environment.Environment INFO     Starting multiprocessing with at most 80 processes running at the same time.
# MainProcess pypet INFO     PROGRESS: Finished 8213/8373 runs [=================== ] 98.1%
# MainProcess pypet INFO     PROGRESS: Finished 8373/8373 runs [====================]100.0%
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED all runs of trajectory
# `results-2020-09-27-12H-23M-15S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING FINAL STORING of trajectory
# `results-2020-09-27-12H-23M-15S`
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED FINAL STORING of trajectory
# `results-2020-09-27-12H-23M-15S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO     All runs of trajectory `results-2020-09-27-12H-23M-15S` were completed successfully.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess root INFO     ----------- Generation 48 -----------
# MainProcess root INFO     Best individual is [3.5780081051007655, 3.5178093150738436, 262.10029036759965, 3.74785670831588, 4943.375342335516, 0.34106454868006486]
# MainProcess root INFO     Score: 0.4115977559522552
# MainProcess root INFO     Fitness: (0.5585464266517041, 0.2528170859538784, 0.9290639271589399)
# MainProcess root INFO     --- Population statistics ---
# MainProcess root INFO     Replacing 0 invalid individuals.
# MainProcess pypet.environment.Environment INFO     I am preparing the Trajectory for the experiment and initialise the store.
# MainProcess pypet.environment.Environment INFO     Initialising the storage for the trajectory.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING runs of trajectory
# `results-2020-09-27-12H-23M-15S`.
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.environment.Environment INFO     Starting multiprocessing with at most 80 processes running at the same time.
# MainProcess pypet INFO     PROGRESS: Finished 8373/8533 runs [=================== ] 98.1%
# MainProcess pypet INFO     PROGRESS: Finished 8533/8533 runs [====================]100.0%
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED all runs of trajectory
# `results-2020-09-27-12H-23M-15S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING FINAL STORING of trajectory
# `results-2020-09-27-12H-23M-15S`
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED FINAL STORING of trajectory
# `results-2020-09-27-12H-23M-15S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO     All runs of trajectory `results-2020-09-27-12H-23M-15S` were completed successfully.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess root INFO     ----------- Generation 49 -----------
# MainProcess root INFO     Best individual is [3.5780081051007655, 3.5178093150738436, 262.10029036759965, 3.74785670831588, 4943.375342335516, 0.34106454868006486]
# MainProcess root INFO     Score: 0.4115977559522552
# MainProcess root INFO     Fitness: (0.5585464266517041, 0.2528170859538784, 0.9290639271589399)
# MainProcess root INFO     --- Population statistics ---
# MainProcess root INFO     --- End of evolution ---
# MainProcess root INFO     Best individual is [3.5780081051007655, 3.5178093150738436, 262.10029036759965, 3.74785670831588, 4943.375342335516, 0.34106454868006486], (0.5585464266517041, 0.2528170859538784, 0.9290639271589399)
# MainProcess root INFO     --- End of evolution ---
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-09-27-12H-23M-15S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-09-27-12H-23M-15S`.

# %%
import dill
fname = os.path.join("/mnt/raid/data/cakan/dill/", "evolution-" + evolution.trajectoryName + ".dill")
print(f"Saving evolution to {fname}")
dill.dump(evolution, open(fname, "wb"))
# Out:
# Saving evolution to /mnt/raid/data/cakan/dill/evolution-results-2020-09-27-12H-23M-15S.dill

# %% [markdown]
# # fMRI-only without adaptation

# %%
MEDIAN_KILLER = False

# %%
model.params['b'] = 0.0

# %%
pars = ParameterSpace(['mue_ext_mean', 'mui_ext_mean', 'Ke_gl', 'sigma_ou'], 
                      [[0.0, 4.0], [0.0, 4.0], [100.0, 400.0], [0.0, 0.5]])

# %%
weightList = [1.0, -1.0]
evolution = Evolution(evaluateSimulation, 
                      pars, 
                      weightList = weightList,                   
                      model = model, 
                      ncores=80,
                      POP_INIT_SIZE=320, 
                      POP_SIZE = 80, 
                      NGEN=20, 
                      algorithm='nsga2',
                      filename="evolution-test-9.0-b-0-fMRI-only.hdf")

# %%
evolution.run(verbose = False)

# %%
import dill
fname = os.path.join("/mnt/raid/data/cakan/dill/", "evolution-" + evolution.trajectoryName + ".dill")
print(f"Saving evolution to {fname}")
dill.dump(evolution, open(fname, "wb"))

# %% [markdown]
# # fMRI-only with adaptation

# %%
MEDIAN_KILLER = False

# %%
pars = ParameterSpace(['mue_ext_mean', 'mui_ext_mean', 'Ke_gl', 'b', 'tauA', 'sigma_ou'], 
                      [[0.0, 4.0], [0.0, 4.0], [100.0, 400.0], [0.0, 20.0], [5.0, 5000.0], [0.0, 0.5]])

# %%
weightList = [1.0, -1.0]
evolution = Evolution(evaluateSimulation, 
                      pars, 
                      weightList = weightList,                   
                      model = model, 
                      ncores=80,
                      POP_INIT_SIZE=320, 
                      POP_SIZE = 80, 
                      NGEN=20, 
                      algorithm='nsga2',
                      filename="evolution-test-9.0-fMRI-only.hdf")
# Out:
# MainProcess root INFO     Trajectory Name: results-2020-07-27-11H-49M-36S
# MainProcess root INFO     Storing data to: /mnt/raid/data/cakan/hdf/evolution-test-9.0-fMRI-only.hdf
# MainProcess root INFO     Trajectory Name: results-2020-07-27-11H-49M-36S
# MainProcess root INFO     Number of cores: 80
# MainProcess pypet.storageservice.HDF5StorageService INFO     I will use the hdf5 file `/mnt/raid/data/cakan/hdf/evolution-test-9.0-fMRI-only.hdf`.
# MainProcess pypet.environment.Environment INFO     Environment initialized.
# MainProcess root INFO     Evolution: Using algorithm: nsga2
# /home/cakan/anaconda/lib/python3.7/site-packages/deap/creator.py:141: RuntimeWarning: A class named 'FitnessMulti' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   RuntimeWarning)
# /home/cakan/anaconda/lib/python3.7/site-packages/deap/creator.py:141: RuntimeWarning: A class named 'Individual' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   RuntimeWarning)
# MainProcess root INFO     Evolution: Individual generation: <function randomParameters at 0x7f6247bcedd0>
# MainProcess root INFO     Evolution: Mating operator: <function cxSimulatedBinaryBounded at 0x7f62501ac680>
# MainProcess root INFO     Evolution: Mutation operator: <function mutPolynomialBounded at 0x7f62501ba9e0>
# MainProcess root INFO     Evolution: Parent selection: <function selTournamentDCD at 0x7f62501b28c0>
# MainProcess root INFO     Evolution: Selection operator: <function selNSGA2 at 0x7f62501ac9e0>

# %%
evolution.run(verbose = False)
# Out:
# MainProcess root INFO     Evaluating initial population of size 320 ...
# MainProcess pypet.trajectory.Trajectory INFO     Your trajectory has not been explored, yet. I will call `f_explore` instead.
# MainProcess pypet.environment.Environment INFO     I am preparing the Trajectory for the experiment and initialise the store.
# MainProcess pypet.environment.Environment INFO     Initialising the storage for the trajectory.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING runs of trajectory
# `results-2020-07-27-11H-49M-36S`.
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.environment.Environment INFO     Starting multiprocessing with at most 80 processes running at the same time.
# MainProcess pypet INFO     PROGRESS: Finished   0/320 runs [                    ]  0.0%
# MainProcess pypet INFO     PROGRESS: Finished  16/320 runs [=                   ]  5.0%, remaining: 0:09:32
# MainProcess pypet INFO     PROGRESS: Finished  32/320 runs [==                  ] 10.0%, remaining: 0:11:15
# MainProcess pypet INFO     PROGRESS: Finished  48/320 runs [===                 ] 15.0%, remaining: 1:16:33
# MainProcess pypet INFO     PROGRESS: Finished  64/320 runs [====                ] 20.0%, remaining: 0:55:55
# MainProcess pypet INFO     PROGRESS: Finished  80/320 runs [=====               ] 25.0%, remaining: 0:42:43
# MainProcess pypet INFO     PROGRESS: Finished  96/320 runs [======              ] 30.0%, remaining: 0:33:43
# MainProcess pypet INFO     PROGRESS: Finished 112/320 runs [=======             ] 35.0%, remaining: 0:27:38
# MainProcess pypet INFO     PROGRESS: Finished 128/320 runs [========            ] 40.0%, remaining: 0:24:38
# MainProcess pypet INFO     PROGRESS: Finished 144/320 runs [=========           ] 45.0%, remaining: 0:21:31
# MainProcess pypet INFO     PROGRESS: Finished 160/320 runs [==========          ] 50.0%, remaining: 0:19:07
# MainProcess pypet INFO     PROGRESS: Finished 176/320 runs [===========         ] 55.0%, remaining: 0:22:44
# MainProcess pypet INFO     PROGRESS: Finished 192/320 runs [============        ] 60.0%, remaining: 0:18:50
# MainProcess pypet INFO     PROGRESS: Finished 208/320 runs [=============       ] 65.0%, remaining: 0:15:24
# MainProcess pypet INFO     PROGRESS: Finished 224/320 runs [==============      ] 70.0%, remaining: 0:12:34
# MainProcess pypet INFO     PROGRESS: Finished 240/320 runs [===============     ] 75.0%, remaining: 0:10:26
# MainProcess pypet INFO     PROGRESS: Finished 256/320 runs [================    ] 80.0%, remaining: 0:08:14
# MainProcess pypet INFO     PROGRESS: Finished 272/320 runs [=================   ] 85.0%, remaining: 0:06:14
# MainProcess pypet INFO     PROGRESS: Finished 288/320 runs [==================  ] 90.0%, remaining: 0:04:20
# MainProcess pypet INFO     PROGRESS: Finished 304/320 runs [=================== ] 95.0%, remaining: 0:02:05
# MainProcess pypet INFO     PROGRESS: Finished 320/320 runs [====================]100.0%
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED all runs of trajectory
# `results-2020-07-27-11H-49M-36S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING FINAL STORING of trajectory
# `results-2020-07-27-11H-49M-36S`
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# /home/cakan/anaconda/lib/python3.7/site-packages/pypet/storageservice.py:4597: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   if (np.issubdtype(val.dtype, str) or
# /home/cakan/anaconda/lib/python3.7/site-packages/pypet/storageservice.py:4598: FutureWarning: Conversion of the second argument of issubdtype from `bytes` to `bytes` is deprecated. In future, it will be treated as `np.bytes_ == np.dtype(bytes).type`.
#   np.issubdtype(val.dtype, bytes)):
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# /home/cakan/anaconda/lib/python3.7/site-packages/pypet/storageservice.py:3110: FutureWarning: Conversion of the second argument of issubdtype from `str` to `str` is deprecated. In future, it will be treated as `np.str_ == np.dtype(str).type`.
#   np.issubdtype(data.dtype, str)):
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED FINAL STORING of trajectory
# `results-2020-07-27-11H-49M-36S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO     All runs of trajectory `results-2020-07-27-11H-49M-36S` were completed successfully.
# /mnt/antares_raid/home/cakan/projects/neurolib/neurolib/optimize/evolution/evolutionaryUtils.py:18: UserWarning: Warning: converting a masked element to nan.
#   f"evolution.gen_{gIdx:06d}.scores", np.array([p.fitness.score for p in pop]),
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Processed 507 nodes in 0m20s (25.14 nodes/s).
# MainProcess pypet.storageservice.HDF5StorageService INFO     Processed 916 nodes in 0m40s (22.69 nodes/s).
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess root INFO     Start of evolution
# MainProcess root INFO     Replacing 0 invalid individuals.
# MainProcess pypet.environment.Environment INFO     I am preparing the Trajectory for the experiment and initialise the store.
# MainProcess pypet.environment.Environment INFO     Initialising the storage for the trajectory.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING runs of trajectory
# `results-2020-07-27-11H-49M-36S`.
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.environment.Environment INFO     Starting multiprocessing with at most 80 processes running at the same time.
# MainProcess pypet INFO     PROGRESS: Finished 320/400 runs [================    ] 80.0%
# MainProcess pypet INFO     PROGRESS: Finished 340/400 runs [=================   ] 85.0%, remaining: 0:38:06
# MainProcess pypet INFO     PROGRESS: Finished 360/400 runs [==================  ] 90.0%, remaining: 0:13:18
# MainProcess pypet INFO     PROGRESS: Finished 380/400 runs [=================== ] 95.0%, remaining: 0:04:33
# MainProcess pypet INFO     PROGRESS: Finished 400/400 runs [====================]100.0%
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED all runs of trajectory
# `results-2020-07-27-11H-49M-36S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING FINAL STORING of trajectory
# `results-2020-07-27-11H-49M-36S`
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED FINAL STORING of trajectory
# `results-2020-07-27-11H-49M-36S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO     All runs of trajectory `results-2020-07-27-11H-49M-36S` were completed successfully.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess root INFO     ----------- Generation 1 -----------
# MainProcess root INFO     Best individual is [2.285702012321614, 2.8750471765543235, 363.88826361671227, 10.540519101494503, 1132.437680450508, 0.31711376972613053]
# MainProcess root INFO     Score: 0.13233277349835332
# MainProcess root INFO     Fitness: (0.551274225704442, 0.2866086787077353)
# MainProcess root INFO     --- Population statistics ---
# MainProcess root INFO     Replacing 0 invalid individuals.
# MainProcess pypet.environment.Environment INFO     I am preparing the Trajectory for the experiment and initialise the store.
# MainProcess pypet.environment.Environment INFO     Initialising the storage for the trajectory.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING runs of trajectory
# `results-2020-07-27-11H-49M-36S`.
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.environment.Environment INFO     Starting multiprocessing with at most 80 processes running at the same time.
# MainProcess pypet INFO     PROGRESS: Finished 400/480 runs [================    ] 83.3%
# MainProcess pypet INFO     PROGRESS: Finished 408/480 runs [=================   ] 85.0%, remaining: 0:09:53
# MainProcess pypet INFO     PROGRESS: Finished 432/480 runs [==================  ] 90.0%, remaining: 0:19:54
# MainProcess pypet INFO     PROGRESS: Finished 456/480 runs [=================== ] 95.0%, remaining: 0:06:01
# MainProcess pypet INFO     PROGRESS: Finished 480/480 runs [====================]100.0%
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED all runs of trajectory
# `results-2020-07-27-11H-49M-36S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING FINAL STORING of trajectory
# `results-2020-07-27-11H-49M-36S`
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED FINAL STORING of trajectory
# `results-2020-07-27-11H-49M-36S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO     All runs of trajectory `results-2020-07-27-11H-49M-36S` were completed successfully.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess root INFO     ----------- Generation 2 -----------
# MainProcess root INFO     Best individual is [2.285702012321614, 2.8750471765543235, 363.88826361671227, 10.540519101494503, 1132.437680450508, 0.31711376972613053]
# MainProcess root INFO     Score: 0.13233277349835332
# MainProcess root INFO     Fitness: (0.551274225704442, 0.2866086787077353)
# MainProcess root INFO     --- Population statistics ---
# MainProcess root INFO     Replacing 0 invalid individuals.
# MainProcess pypet.environment.Environment INFO     I am preparing the Trajectory for the experiment and initialise the store.
# MainProcess pypet.environment.Environment INFO     Initialising the storage for the trajectory.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING runs of trajectory
# `results-2020-07-27-11H-49M-36S`.
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.environment.Environment INFO     Starting multiprocessing with at most 80 processes running at the same time.
# MainProcess pypet INFO     PROGRESS: Finished 480/560 runs [=================   ] 85.7%
# MainProcess pypet INFO     PROGRESS: Finished 504/560 runs [==================  ] 90.0%, remaining: 0:29:20
# MainProcess pypet INFO     PROGRESS: Finished 532/560 runs [=================== ] 95.0%, remaining: 0:07:07
# MainProcess pypet INFO     PROGRESS: Finished 560/560 runs [====================]100.0%
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED all runs of trajectory
# `results-2020-07-27-11H-49M-36S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING FINAL STORING of trajectory
# `results-2020-07-27-11H-49M-36S`
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED FINAL STORING of trajectory
# `results-2020-07-27-11H-49M-36S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO     All runs of trajectory `results-2020-07-27-11H-49M-36S` were completed successfully.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess root INFO     ----------- Generation 3 -----------
# MainProcess root INFO     Best individual is [2.285702012321614, 2.8750471765543235, 363.88826361671227, 10.540519101494503, 1132.437680450508, 0.31711376972613053]
# MainProcess root INFO     Score: 0.13233277349835332
# MainProcess root INFO     Fitness: (0.551274225704442, 0.2866086787077353)
# MainProcess root INFO     --- Population statistics ---
# MainProcess root INFO     Replacing 0 invalid individuals.
# MainProcess pypet.environment.Environment INFO     I am preparing the Trajectory for the experiment and initialise the store.
# MainProcess pypet.environment.Environment INFO     Initialising the storage for the trajectory.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING runs of trajectory
# `results-2020-07-27-11H-49M-36S`.
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.environment.Environment INFO     Starting multiprocessing with at most 80 processes running at the same time.
# MainProcess pypet INFO     PROGRESS: Finished 560/640 runs [=================   ] 87.5%
# MainProcess pypet INFO     PROGRESS: Finished 576/640 runs [==================  ] 90.0%, remaining: 0:50:24
# MainProcess pypet INFO     PROGRESS: Finished 608/640 runs [=================== ] 95.0%, remaining: 0:08:52
# MainProcess pypet INFO     PROGRESS: Finished 640/640 runs [====================]100.0%
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED all runs of trajectory
# `results-2020-07-27-11H-49M-36S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING FINAL STORING of trajectory
# `results-2020-07-27-11H-49M-36S`
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED FINAL STORING of trajectory
# `results-2020-07-27-11H-49M-36S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO     All runs of trajectory `results-2020-07-27-11H-49M-36S` were completed successfully.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess root INFO     ----------- Generation 4 -----------
# MainProcess root INFO     Best individual is [2.269122241783596, 2.708482064489508, 251.25376534328814, 5.348895866129874, 3358.8217510059976, 0.3152042346791967]
# MainProcess root INFO     Score: 0.1348226465178134
# MainProcess root INFO     Fitness: (0.5785410356577845, 0.3088957426221577)
# MainProcess root INFO     --- Population statistics ---
# MainProcess root INFO     Replacing 0 invalid individuals.
# MainProcess pypet.environment.Environment INFO     I am preparing the Trajectory for the experiment and initialise the store.
# MainProcess pypet.environment.Environment INFO     Initialising the storage for the trajectory.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING runs of trajectory
# `results-2020-07-27-11H-49M-36S`.
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.environment.Environment INFO     Starting multiprocessing with at most 80 processes running at the same time.
# MainProcess pypet INFO     PROGRESS: Finished 640/720 runs [=================   ] 88.9%
# MainProcess pypet INFO     PROGRESS: Finished 648/720 runs [==================  ] 90.0%, remaining: 0:10:08
# MainProcess pypet INFO     PROGRESS: Finished 684/720 runs [=================== ] 95.0%, remaining: 0:10:42
# MainProcess pypet INFO     PROGRESS: Finished 720/720 runs [====================]100.0%
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED all runs of trajectory
# `results-2020-07-27-11H-49M-36S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING FINAL STORING of trajectory
# `results-2020-07-27-11H-49M-36S`
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED FINAL STORING of trajectory
# `results-2020-07-27-11H-49M-36S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO     All runs of trajectory `results-2020-07-27-11H-49M-36S` were completed successfully.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess root INFO     ----------- Generation 5 -----------
# MainProcess root INFO     Best individual is [2.269122241783596, 2.708482064489508, 251.25376534328814, 5.348895866129874, 3358.8217510059976, 0.3152042346791967]
# MainProcess root INFO     Score: 0.1348226465178134
# MainProcess root INFO     Fitness: (0.5785410356577845, 0.3088957426221577)
# MainProcess root INFO     --- Population statistics ---
# MainProcess root INFO     Replacing 0 invalid individuals.
# MainProcess pypet.environment.Environment INFO     I am preparing the Trajectory for the experiment and initialise the store.
# MainProcess pypet.environment.Environment INFO     Initialising the storage for the trajectory.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING runs of trajectory
# `results-2020-07-27-11H-49M-36S`.
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.environment.Environment INFO     Starting multiprocessing with at most 80 processes running at the same time.
# MainProcess pypet INFO     PROGRESS: Finished 720/800 runs [==================  ] 90.0%
# MainProcess pypet INFO     PROGRESS: Finished 760/800 runs [=================== ] 95.0%, remaining: 0:13:30
# MainProcess pypet INFO     PROGRESS: Finished 800/800 runs [====================]100.0%
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED all runs of trajectory
# `results-2020-07-27-11H-49M-36S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING FINAL STORING of trajectory
# `results-2020-07-27-11H-49M-36S`
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED FINAL STORING of trajectory
# `results-2020-07-27-11H-49M-36S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO     All runs of trajectory `results-2020-07-27-11H-49M-36S` were completed successfully.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess root INFO     ----------- Generation 6 -----------
# MainProcess root INFO     Best individual is [2.269122241783596, 2.708482064489508, 251.25376534328814, 5.348895866129874, 3358.8217510059976, 0.3152042346791967]
# MainProcess root INFO     Score: 0.1348226465178134
# MainProcess root INFO     Fitness: (0.5785410356577845, 0.3088957426221577)
# MainProcess root INFO     --- Population statistics ---
# MainProcess root INFO     Replacing 0 invalid individuals.
# MainProcess pypet.environment.Environment INFO     I am preparing the Trajectory for the experiment and initialise the store.
# MainProcess pypet.environment.Environment INFO     Initialising the storage for the trajectory.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING runs of trajectory
# `results-2020-07-27-11H-49M-36S`.
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.environment.Environment INFO     Starting multiprocessing with at most 80 processes running at the same time.
# MainProcess pypet INFO     PROGRESS: Finished 800/880 runs [==================  ] 90.9%
# MainProcess pypet INFO     PROGRESS: Finished 836/880 runs [=================== ] 95.0%, remaining: 0:16:50
# MainProcess pypet INFO     PROGRESS: Finished 880/880 runs [====================]100.0%
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED all runs of trajectory
# `results-2020-07-27-11H-49M-36S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING FINAL STORING of trajectory
# `results-2020-07-27-11H-49M-36S`
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED FINAL STORING of trajectory
# `results-2020-07-27-11H-49M-36S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO     All runs of trajectory `results-2020-07-27-11H-49M-36S` were completed successfully.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess root INFO     ----------- Generation 7 -----------
# MainProcess root INFO     Best individual is [2.300261484713471, 2.8557829183764745, 370.35546354366824, 10.540519101494503, 1132.437680450508, 0.32062108682557594]
# MainProcess root INFO     Score: 0.1426576573196618
# MainProcess root INFO     Fitness: (0.5724672524988086, 0.287151937859485)
# MainProcess root INFO     --- Population statistics ---
# MainProcess root INFO     Replacing 0 invalid individuals.
# MainProcess pypet.environment.Environment INFO     I am preparing the Trajectory for the experiment and initialise the store.
# MainProcess pypet.environment.Environment INFO     Initialising the storage for the trajectory.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING runs of trajectory
# `results-2020-07-27-11H-49M-36S`.
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.environment.Environment INFO     Starting multiprocessing with at most 80 processes running at the same time.
# MainProcess pypet INFO     PROGRESS: Finished 880/960 runs [==================  ] 91.7%
# MainProcess pypet INFO     PROGRESS: Finished 912/960 runs [=================== ] 95.0%, remaining: 0:19:59
# MainProcess pypet INFO     PROGRESS: Finished 960/960 runs [====================]100.0%
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED all runs of trajectory
# `results-2020-07-27-11H-49M-36S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING FINAL STORING of trajectory
# `results-2020-07-27-11H-49M-36S`
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED FINAL STORING of trajectory
# `results-2020-07-27-11H-49M-36S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO     All runs of trajectory `results-2020-07-27-11H-49M-36S` were completed successfully.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess root INFO     ----------- Generation 8 -----------
# MainProcess root INFO     Best individual is [2.300261484713471, 2.8557829183764745, 370.35546354366824, 10.540519101494503, 1132.437680450508, 0.32062108682557594]
# MainProcess root INFO     Score: 0.1426576573196618
# MainProcess root INFO     Fitness: (0.5724672524988086, 0.287151937859485)
# MainProcess root INFO     --- Population statistics ---
# MainProcess root INFO     Replacing 0 invalid individuals.
# MainProcess pypet.environment.Environment INFO     I am preparing the Trajectory for the experiment and initialise the store.
# MainProcess pypet.environment.Environment INFO     Initialising the storage for the trajectory.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING runs of trajectory
# `results-2020-07-27-11H-49M-36S`.
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.environment.Environment INFO     Starting multiprocessing with at most 80 processes running at the same time.
# MainProcess pypet INFO     PROGRESS: Finished 960/1040 runs [==================  ] 92.3%
# MainProcess pypet INFO     PROGRESS: Finished 988/1040 runs [=================== ] 95.0%, remaining: 0:25:33
# MainProcess pypet INFO     PROGRESS: Finished 1040/1040 runs [====================]100.0%
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED all runs of trajectory
# `results-2020-07-27-11H-49M-36S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING FINAL STORING of trajectory
# `results-2020-07-27-11H-49M-36S`
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED FINAL STORING of trajectory
# `results-2020-07-27-11H-49M-36S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO     All runs of trajectory `results-2020-07-27-11H-49M-36S` were completed successfully.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess root INFO     ----------- Generation 9 -----------
# MainProcess root INFO     Best individual is [2.300261484713471, 2.8557829183764745, 370.35546354366824, 10.540519101494503, 1132.437680450508, 0.32062108682557594]
# MainProcess root INFO     Score: 0.1426576573196618
# MainProcess root INFO     Fitness: (0.5724672524988086, 0.287151937859485)
# MainProcess root INFO     --- Population statistics ---
# MainProcess root INFO     Replacing 0 invalid individuals.
# MainProcess pypet.environment.Environment INFO     I am preparing the Trajectory for the experiment and initialise the store.
# MainProcess pypet.environment.Environment INFO     Initialising the storage for the trajectory.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING runs of trajectory
# `results-2020-07-27-11H-49M-36S`.
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.environment.Environment INFO     Starting multiprocessing with at most 80 processes running at the same time.
# MainProcess pypet INFO     PROGRESS: Finished 1040/1120 runs [==================  ] 92.9%
# MainProcess pypet INFO     PROGRESS: Finished 1064/1120 runs [=================== ] 95.0%, remaining: 0:31:03
# ...
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED all runs of trajectory
# `results-2020-07-27-11H-49M-36S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING FINAL STORING of trajectory
# `results-2020-07-27-11H-49M-36S`
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED FINAL STORING of trajectory
# `results-2020-07-27-11H-49M-36S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO     All runs of trajectory `results-2020-07-27-11H-49M-36S` were completed successfully.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess root INFO     ----------- Generation 16 -----------
# MainProcess root INFO     Best individual is [2.269122241783596, 2.5412535293121756, 292.8802105171533, 4.18364481365586, 3539.1104727636343, 0.29168589508408654]
# MainProcess root INFO     Score: 0.14925977990873904
# MainProcess root INFO     Fitness: (0.5629339015903104, 0.26441434177283235)
# MainProcess root INFO     --- Population statistics ---
# MainProcess root INFO     Replacing 0 invalid individuals.
# MainProcess pypet.environment.Environment INFO     I am preparing the Trajectory for the experiment and initialise the store.
# MainProcess pypet.environment.Environment INFO     Initialising the storage for the trajectory.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING runs of trajectory
# `results-2020-07-27-11H-49M-36S`.
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.environment.Environment INFO     Starting multiprocessing with at most 80 processes running at the same time.
# MainProcess pypet INFO     PROGRESS: Finished 1600/1680 runs [=================== ] 95.2%
# MainProcess pypet INFO     PROGRESS: Finished 1680/1680 runs [====================]100.0%
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED all runs of trajectory
# `results-2020-07-27-11H-49M-36S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING FINAL STORING of trajectory
# `results-2020-07-27-11H-49M-36S`
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED FINAL STORING of trajectory
# `results-2020-07-27-11H-49M-36S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO     All runs of trajectory `results-2020-07-27-11H-49M-36S` were completed successfully.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess root INFO     ----------- Generation 17 -----------
# MainProcess root INFO     Best individual is [2.269122241783596, 2.5412535293121756, 292.8802105171533, 4.18364481365586, 3539.1104727636343, 0.29168589508408654]
# MainProcess root INFO     Score: 0.14925977990873904
# MainProcess root INFO     Fitness: (0.5629339015903104, 0.26441434177283235)
# MainProcess root INFO     --- Population statistics ---
# MainProcess root INFO     Replacing 0 invalid individuals.
# MainProcess pypet.environment.Environment INFO     I am preparing the Trajectory for the experiment and initialise the store.
# MainProcess pypet.environment.Environment INFO     Initialising the storage for the trajectory.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING runs of trajectory
# `results-2020-07-27-11H-49M-36S`.
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.environment.Environment INFO     Starting multiprocessing with at most 80 processes running at the same time.
# MainProcess pypet INFO     PROGRESS: Finished 1680/1760 runs [=================== ] 95.5%
# MainProcess pypet INFO     PROGRESS: Finished 1760/1760 runs [====================]100.0%
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED all runs of trajectory
# `results-2020-07-27-11H-49M-36S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING FINAL STORING of trajectory
# `results-2020-07-27-11H-49M-36S`
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED FINAL STORING of trajectory
# `results-2020-07-27-11H-49M-36S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO     All runs of trajectory `results-2020-07-27-11H-49M-36S` were completed successfully.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess root INFO     ----------- Generation 18 -----------
# MainProcess root INFO     Best individual is [2.269122241783596, 2.5412535293121756, 292.8802105171533, 4.18364481365586, 3539.1104727636343, 0.29168589508408654]
# MainProcess root INFO     Score: 0.14925977990873904
# MainProcess root INFO     Fitness: (0.5629339015903104, 0.26441434177283235)
# MainProcess root INFO     --- Population statistics ---
# MainProcess root INFO     Replacing 0 invalid individuals.
# MainProcess pypet.environment.Environment INFO     I am preparing the Trajectory for the experiment and initialise the store.
# MainProcess pypet.environment.Environment INFO     Initialising the storage for the trajectory.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING runs of trajectory
# `results-2020-07-27-11H-49M-36S`.
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.environment.Environment INFO     Starting multiprocessing with at most 80 processes running at the same time.
# MainProcess pypet INFO     PROGRESS: Finished 1760/1840 runs [=================== ] 95.7%
# MainProcess pypet INFO     PROGRESS: Finished 1840/1840 runs [====================]100.0%
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED all runs of trajectory
# `results-2020-07-27-11H-49M-36S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING FINAL STORING of trajectory
# `results-2020-07-27-11H-49M-36S`
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED FINAL STORING of trajectory
# `results-2020-07-27-11H-49M-36S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO     All runs of trajectory `results-2020-07-27-11H-49M-36S` were completed successfully.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess root INFO     ----------- Generation 19 -----------
# MainProcess root INFO     Best individual is [2.269122241783596, 2.5412535293121756, 292.8802105171533, 4.18364481365586, 3539.1104727636343, 0.29168589508408654]
# MainProcess root INFO     Score: 0.14925977990873904
# MainProcess root INFO     Fitness: (0.5629339015903104, 0.26441434177283235)
# MainProcess root INFO     --- Population statistics ---
# MainProcess root INFO     --- End of evolution ---
# MainProcess root INFO     Best individual is [2.269122241783596, 2.5412535293121756, 292.8802105171533, 4.18364481365586, 3539.1104727636343, 0.29168589508408654], (0.5629339015903104, 0.26441434177283235)
# MainProcess root INFO     --- End of evolution ---
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2020-07-27-11H-49M-36S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2020-07-27-11H-49M-36S`.

# %%
import dill
fname = os.path.join("/mnt/raid/data/cakan/dill/", "evolution-" + evolution.trajectoryName + ".dill")
print(f"Saving evolution to {fname}")
dill.dump(evolution, open(fname, "wb"))
# Out:
# Saving evolution to /mnt/raid/data/cakan/dill/evolution-results-2020-07-27-11H-49M-36S.dill
